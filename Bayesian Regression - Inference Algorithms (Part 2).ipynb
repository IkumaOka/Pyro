# %%
# %reset -sf

# %%
import logging
import os

import torch
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from torch.distributions import constraints

import pyro
import pyro.distributions as dist
import pyro.optim as optim

pyro.set_rng_seed(1)
assert pyro.__version__.startswith('1.3.1')

# %%
# %matplotlib inline
plt.style.use('default')

logging.basicConfig(format='%(message)s', level=logging.INFO)
# Enable validation checks
pyro.enable_validation(True)
smoke_test = ('CI' in os.environ)
pyro.set_rng_seed(1)
DATA_URL = "https://d2hg8soec8ck9v.cloudfront.net/datasets/rugged_data.csv"
rugged_data = pd.read_csv(DATA_URL, encoding="ISO-8859-1")
rugged_data
# Out:
#     isocode  isonum                               country  rugged  \
# 0       ABW     533                                 Aruba   0.462
# 1       AFG       4                           Afghanistan   2.518
# 2       AGO      24                                Angola   0.858
# 3       AIA     660                              Anguilla   0.013
# 4       ALB       8                               Albania   3.427
# 5       AND      20                               Andorra   5.717
# 6       ANT     530                  Netherlands Antilles   0.255
# 7       ARE     784                  United Arab Emirates   0.769
# 8       ARG      32                             Argentina   0.775
# 9       ARM      51                               Armenia   2.688
# 10      ASM      16                        American Samoa   2.647
# 11      ATG      28                   Antigua and Barbuda   0.006
# 12      AUS      36                             Australia   0.143
# 13      AUT      40                               Austria   3.513
# 14      AZE      31                            Azerbaijan   1.672
# 15      BDI     108                               Burundi   1.780
# 16      BEL      56                               Belgium   0.388
# 17      BEN     204                                 Benin   0.141
# 18      BFA     854                          Burkina Faso   0.236
# 19      BGD      50                            Bangladesh   0.186
# 20      BGR     100                              Bulgaria   1.479
# 21      BHR      48                               Bahrain   0.231
# 22      BHS      44                               Bahamas   0.055
# 23      BIH      70                Bosnia and Herzegovina   2.311
# 24      BLR     112                               Belarus   0.164
# 25      BLZ      84                                Belize   0.607
# 26      BMU      60                               Bermuda   0.015
# 27      BOL      68                               Bolivia   0.853
# 28      BRA      76                                Brazil   0.240
# 29      BRB      52                              Barbados   0.963
# ..      ...     ...                                   ...     ...
# 204     TJK     762                            Tajikistan   5.301
# 205     TKL     772                               Tokelau   0.000
# 206     TKM     795                          Turkmenistan   0.284
# 207     TLS     626                           Timor-Leste   1.850
# 208     TON     776                                 Tonga   0.773
# 209     TTO     780                   Trinidad and Tobago   0.603
# 210     TUN     788                               Tunisia   0.726
# 211     TUR     792                                Turkey   2.620
# 212     TUV     798                                Tuvalu   0.025
# 213     TWN     158                                Taiwan   3.490
# 214     TZA     834           United Republic of Tanzania   0.677
# 215     UGA     800                                Uganda   0.913
# 216     UKR     804                               Ukraine   0.416
# 217     UMI     581  United States Minor Outlying Islands   0.005
# 218     URY     858                               Uruguay   0.435
# 219     USA     840              United States of America   1.073
# 220     UZB     860                            Uzbekistan   0.526
# 221     VAT     336                              Holy See   0.438
# 222     VCT     670      Saint Vincent and the Grenadines   3.071
# 223     VEN     862    Venezuela (Bolivarian Republic of)   0.634
# 224     VGB      92                British Virgin Islands   1.257
# 225     VIR     850          United States Virgin Islands   1.404
# 226     VNM     704                              Viet Nam   2.054
# 227     VUT     548                               Vanuatu   1.729
# 228     WLF     876             Wallis and Futuna Islands   1.306
# 229     WSM     882                                 Samoa   1.677
# 230     YEM     887                                 Yemen   2.323
# 231     ZAF     710                          South Africa   1.761
# 232     ZMB     894                                Zambia   0.533
# 233     ZWE     716                              Zimbabwe   1.194
#
#      rugged_popw  rugged_slope  rugged_lsd  rugged_pc  land_area     lat  ...  \
# 0          0.380         1.226       0.144      0.000       18.0  12.508  ...
# 1          1.469         7.414       0.720     39.004    65209.0  33.833  ...
# 2          0.714         2.274       0.228      4.906   124670.0 -12.299  ...
# 3          0.010         0.026       0.006      0.000        9.0  18.231  ...
# 4          1.597        10.451       1.006     62.133     2740.0  41.143  ...
# 5          6.722        17.774       1.616     99.064       47.0  42.551  ...
# 6          0.039         0.680       0.080      0.000       80.0  12.725  ...
# 7          0.316         2.112       0.191      6.142     8360.0  23.913  ...
# 8          0.220         2.268       0.226      9.407   273669.0 -35.396  ...
# 9          0.934         8.178       0.799     50.556     2820.0  40.294  ...
# 10         1.630         7.032       0.792     44.303       20.0 -14.200  ...
# 11         0.003         0.012       0.003      0.000       44.0  17.271  ...
# 12         0.183         0.405       0.045      0.685   768230.0 -25.733  ...
# 13         1.152        11.095       1.008     54.307     8245.0  47.589  ...
# 14         0.534         5.080       0.490     27.713     8260.5  40.288  ...
# 15         1.586         4.721       0.500     27.519     2568.0  -3.365  ...
# 16         0.261         1.239       0.109      0.178     3023.0  50.642  ...
# 17         0.099         0.377       0.045      0.014    11062.0   9.650  ...
# 18         0.214         0.638       0.066      0.051    27360.0  12.274  ...
# 19         0.065         0.502       0.053      1.817    13017.0  23.848  ...
# 20         0.711         4.498       0.427     20.196    11063.0  42.765  ...
# 21         0.163         0.627       0.063      0.000       71.0  26.025  ...
# 22         0.100         0.144       0.017      0.000     1001.0  24.255  ...
# 23         1.288         7.075       0.665     40.253     5120.0  44.175  ...
# 24         0.208         0.540       0.046      0.000    20748.0  53.542  ...
# 25         0.226         1.616       0.174      6.568     2281.0  17.205  ...
# 26         0.014         0.030       0.006      0.000        5.0  32.310  ...
# 27         0.911         2.343       0.258     13.570   108438.0 -16.710  ...
# 28         0.250         0.654       0.076      0.558   845942.0 -10.775  ...
# 29         0.695         2.581       0.289      3.823       43.0  13.167  ...
# ..           ...           ...         ...        ...        ...     ...  ...
# 204        1.033        15.976       1.540     75.473    13996.0  38.527  ...
# 205        0.000         0.000       0.000      0.000        1.0  -9.088  ...
# 206        0.248         0.834       0.082      1.426    46993.0  39.194  ...
# 207        1.286         5.001       0.584     28.298     1487.0  -8.827  ...
# 208        0.070         1.992       0.224      9.737       72.0 -19.859  ...
# 209        0.521         1.611       0.184      5.099      513.0  10.469  ...
# 210        0.585         2.079       0.198      7.434    15536.0  34.120  ...
# 211        1.192         7.773       0.732     40.909    76963.0  39.061  ...
# 212        0.020         0.055       0.008      0.000        3.0  -7.414  ...
# 213        0.429         9.785       1.032     56.543     3615.0  23.752  ...
# 214        0.541         1.814       0.201      5.346    88580.0  -6.266  ...
# 215        0.779         2.424       0.251      8.765    19710.0   1.282  ...
# 216        0.359         1.317       0.117      1.988    57935.0  49.009  ...
# 217        0.035         0.011       0.001      0.000        NaN   7.141  ...
# 218        0.391         1.283       0.114      0.136    17502.0 -32.802  ...
# 219        0.333         3.384       0.304     14.317   916192.0  45.718  ...
# 220        0.243         1.589       0.154      5.782    42540.0  41.633  ...
# 221        0.428         1.162       0.126      0.000        NaN  41.904  ...
# 222        1.878         8.401       0.892     61.286       39.0  13.185  ...
# 223        0.594         1.716       0.202      5.994    88205.0   7.132  ...
# 224        1.873         3.131       0.340     19.147       15.0  18.511  ...
# 225        1.268         3.652       0.395     17.088       35.0  17.985  ...
# 226        0.439         5.603       0.583     36.775    31106.0  16.643  ...
# 227        1.041         4.709       0.545     24.993     1219.0 -16.196  ...
# 228        0.977         3.505       0.400     24.238       14.0 -13.829  ...
# 229        0.968         4.644       0.549     22.244      283.0 -13.738  ...
# 230        2.197         6.155       0.591     33.060    52797.0  15.863  ...
# 231        1.318         4.942       0.450     23.957   121447.0 -29.004  ...
# 232        0.506         1.422       0.145      2.455    74339.0 -13.458  ...
# 233        1.106         3.232       0.306     13.837    38685.0 -19.000  ...
#
#      africa_region_w  africa_region_e  africa_region_c  slave_exports  \
# 0                  0                0                0          0.000
# 1                  0                0                0          0.000
# 2                  0                0                1    3610000.000
# 3                  0                0                0          0.000
# 4                  0                0                0          0.000
# 5                  0                0                0          0.000
# 6                  0                0                0          0.000
# 7                  0                0                0          0.000
# 8                  0                0                0          0.000
# 9                  0                0                0          0.000
# 10                 0                0                0          0.000
# 11                 0                0                0          0.000
# 12                 0                0                0          0.000
# 13                 0                0                0          0.000
# 14                 0                0                0          0.000
# 15                 0                1                0         86.997
# 16                 0                0                0          0.000
# 17                 1                0                0     457000.000
# 18                 1                0                0     167000.000
# 19                 0                0                0          0.000
# 20                 0                0                0          0.000
# 21                 0                0                0          0.000
# 22                 0                0                0          0.000
# 23                 0                0                0          0.000
# 24                 0                0                0          0.000
# 25                 0                0                0          0.000
# 26                 0                0                0          0.000
# 27                 0                0                0          0.000
# 28                 0                0                0          0.000
# 29                 0                0                0          0.000
# ..               ...              ...              ...            ...
# 204                0                0                0          0.000
# 205                0                0                0          0.000
# 206                0                0                0          0.000
# 207                0                0                0          0.000
# 208                0                0                0          0.000
# 209                0                0                0          0.000
# 210                0                0                0          0.000
# 211                0                0                0          0.000
# 212                0                0                0          0.000
# 213                0                0                0          0.000
# 214                0                1                0     535000.000
# 215                0                1                0       4553.603
# 216                0                0                0          0.000
# 217                0                0                0          0.000
# 218                0                0                0          0.000
# 219                0                0                0          0.000
# 220                0                0                0          0.000
# 221                0                0                0          0.000
# 222                0                0                0          0.000
# 223                0                0                0          0.000
# 224                0                0                0          0.000
# 225                0                0                0          0.000
# 226                0                0                0          0.000
# 227                0                0                0          0.000
# 228                0                0                0          0.000
# 229                0                0                0          0.000
# 230                0                0                0          0.000
# 231                0                0                0       2030.663
# 232                0                0                0      27957.102
# 233                0                0                0       1088.177
#
#      dist_slavemkt_atlantic  dist_slavemkt_indian  dist_slavemkt_saharan  \
# 0                       NaN                   NaN                    NaN
# 1                       NaN                   NaN                    NaN
# 2                     5.669                 6.981                  4.926
# 3                       NaN                   NaN                    NaN
# 4                       NaN                   NaN                    NaN
# 5                       NaN                   NaN                    NaN
# 6                       NaN                   NaN                    NaN
# 7                       NaN                   NaN                    NaN
# 8                       NaN                   NaN                    NaN
# 9                       NaN                   NaN                    NaN
# 10                      NaN                   NaN                    NaN
# 11                      NaN                   NaN                    NaN
# 12                      NaN                   NaN                    NaN
# 13                      NaN                   NaN                    NaN
# 14                      NaN                   NaN                    NaN
# 15                   10.626                 2.570                  3.719
# 16                      NaN                   NaN                    NaN
# 17                    5.121                 9.234                  2.835
# 18                    4.775                 9.299                  2.764
# 19                      NaN                   NaN                    NaN
# 20                      NaN                   NaN                    NaN
# 21                      NaN                   NaN                    NaN
# 22                      NaN                   NaN                    NaN
# 23                      NaN                   NaN                    NaN
# 24                      NaN                   NaN                    NaN
# 25                      NaN                   NaN                    NaN
# 26                      NaN                   NaN                    NaN
# 27                      NaN                   NaN                    NaN
# 28                      NaN                   NaN                    NaN
# 29                      NaN                   NaN                    NaN
# ..                      ...                   ...                    ...
# 204                     NaN                   NaN                    NaN
# 205                     NaN                   NaN                    NaN
# 206                     NaN                   NaN                    NaN
# 207                     NaN                   NaN                    NaN
# 208                     NaN                   NaN                    NaN
# 209                     NaN                   NaN                    NaN
# 210                   7.480                15.833                  0.310
# 211                     NaN                   NaN                    NaN
# 212                     NaN                   NaN                    NaN
# 213                     NaN                   NaN                    NaN
# 214                  10.595                 2.558                  4.056
# 215                  10.996                 2.699                  3.204
# 216                     NaN                   NaN                    NaN
# 217                     NaN                   NaN                    NaN
# 218                     NaN                   NaN                    NaN
# 219                     NaN                   NaN                    NaN
# 220                     NaN                   NaN                    NaN
# 221                     NaN                   NaN                    NaN
# 222                     NaN                   NaN                    NaN
# 223                     NaN                   NaN                    NaN
# 224                     NaN                   NaN                    NaN
# 225                     NaN                   NaN                    NaN
# 226                     NaN                   NaN                    NaN
# 227                     NaN                   NaN                    NaN
# 228                     NaN                   NaN                    NaN
# 229                     NaN                   NaN                    NaN
# 230                     NaN                   NaN                    NaN
# 231                   6.766                 3.457                  6.584
# 232                   9.027                 2.389                  4.849
# 233                   9.027                 2.389                  5.454
#
#      dist_slavemkt_redsea   pop_1400  european_descent
# 0                     NaN      614.0               NaN
# 1                     NaN  1870829.0             0.000
# 2                   3.872  1223208.0             2.000
# 3                     NaN        NaN               NaN
# 4                     NaN   200000.0           100.000
# 5                     NaN        NaN               NaN
# 6                     NaN     1802.0               NaN
# 7                     NaN    19200.0             0.000
# 8                     NaN   276632.0            89.889
# 9                     NaN   105743.0             0.500
# 10                    NaN        NaN               NaN
# 11                    NaN      747.0               NaN
# 12                    NaN   200000.0            89.954
# 13                    NaN  1250000.0            98.400
# 14                    NaN   226250.0             4.000
# 15                  2.215   239693.0             0.000
# 16                    NaN   773466.0            98.000
# 17                  3.902   348867.0             0.000
# 18                  4.239   692976.0             0.000
# 19                    NaN  9103705.0             0.000
# 20                    NaN   894427.0            98.850
# 21                    NaN    31897.0             0.000
# 22                    NaN     1276.0               NaN
# 23                    NaN   366341.0           100.000
# 24                    NaN   487364.0           100.000
# 25                    NaN     5326.0            39.910
# 26                    NaN      601.0               NaN
# 27                    NaN   829897.0            26.732
# 28                    NaN   931150.0            74.430
# 29                    NaN     3403.0               NaN
# ..                    ...        ...               ...
# 204                   NaN   286375.0             3.900
# 205                   NaN        NaN               NaN
# 206                   NaN   226444.0             5.500
# 207                   NaN    36325.0             0.000
# 208                   NaN    19021.0               NaN
# 209                   NaN    10258.0             7.100
# 210                 3.205   836512.0             0.000
# 211                   NaN  6438306.0            10.000
# 212                   NaN        NaN               NaN
# 213                   NaN   174110.0             0.000
# 214                 2.187  1496403.0             0.000
# 215                 1.650  1322790.0             0.000
# 216                   NaN  2347003.0           100.000
# 217                   NaN        NaN               NaN
# 218                   NaN        NaN            91.890
# 219                   NaN   783496.0            76.020
# 220                   NaN  1180650.0             7.500
# 221                   NaN        NaN               NaN
# 222                   NaN     1081.0               NaN
# 223                   NaN   377635.0            54.500
# 224                   NaN      120.0               NaN
# 225                   NaN      432.0               NaN
# 226                   NaN  1665106.0             0.000
# 227                   NaN    22994.0               NaN
# 228                   NaN        NaN               NaN
# 229                   NaN    33072.0               NaN
# 230                   NaN  2250000.0             0.000
# 231                 4.895   486527.0            18.000
# 232                 3.253   348220.0             1.000
# 233                 3.696   174110.0             1.000
#
# [234 rows x 51 columns]

# %%
def model(is_cont_africa, ruggedness, log_gdp):
    """
     pyro.paramに学習させたいパラメータを登録する
     b_a: is_cont_africa
     b_r: ruggedness
     a: 切片
     b_ar: b_aとb_rの相関係数
    """
    a = pyro.sample("a", dist.Normal(0., 10.))
    b_a = pyro.sample("bA", dist.Normal(0., 1.))
    b_r = pyro.sample("bR", dist.Normal(0., 1.))
    b_ar = pyro.sample("bAR", dist.Normal(0., 1.))
    sigma = pyro.sample("sigma", dist.Uniform(0., 10.))
    # NNと同じ計算している？
    mean = a + b_a * is_cont_africa + b_r * ruggedness + b_ar * is_cont_africa * ruggedness
    with pyro.plate("data", len(ruggedness)):
        pyro.sample("obs", dist.Normal(mean, sigma), obs=log_gdp)

# %%
# guideで定義する変数はmodelで定義した変数と同じ
# guideとmodelで事前分布の種類は同じだが、guideでは分布のパラメータがランダムに生成されている
def guide(is_cont_africa, ruggedness, log_gdp):
    a_loc = pyro.param('a_loc', torch.tensor(0.))
    a_scale = pyro.param('a_scale', torch.tensor(1.),
                         constraint=constraints.positive)
    sigma_loc = pyro.param('sigma_loc', torch.tensor(1.),
                             constraint=constraints.positive)
    weights_loc = pyro.param('weights_loc', torch.randn(3))
    weights_scale = pyro.param('weights_scale', torch.ones(3),
                               constraint=constraints.positive)
    a = pyro.sample("a", dist.Normal(a_loc, a_scale))
    b_a = pyro.sample("bA", dist.Normal(weights_loc[0], weights_scale[0]))
    b_r = pyro.sample("bR", dist.Normal(weights_loc[1], weights_scale[1]))
    b_ar = pyro.sample("bAR", dist.Normal(weights_loc[2], weights_scale[2]))
    sigma = pyro.sample("sigma", dist.Normal(sigma_loc, torch.tensor(0.05)))
    mean = a + b_a * is_cont_africa + b_r * ruggedness + b_ar * is_cont_africa * ruggedness

# %%
# Utility function to print latent sites' quantile information.
def summary(samples):
    site_stats = {}
    for site_name, values in samples.items():
        marginal_site = pd.DataFrame(values)
        describe = marginal_site.describe(percentiles=[.05, 0.25, 0.5, 0.75, 0.95]).transpose()
        site_stats[site_name] = describe[["mean", "std", "5%", "25%", "50%", "75%", "95%"]]
    return site_stats

# Prepare training data
df = rugged_data[["cont_africa", "rugged", "rgdppc_2000"]]
df = df[np.isfinite(df.rgdppc_2000)]
df["rgdppc_2000"] = np.log(df["rgdppc_2000"])
train = torch.tensor(df.values, dtype=torch.float)

# %%
from pyro.infer import SVI, Trace_ELBO


svi = SVI(model,
          guide,
          optim.Adam({"lr": .05}),
          loss=Trace_ELBO())

is_cont_africa, ruggedness, log_gdp = train[:, 0], train[:, 1], train[:, 2]
pyro.clear_param_store()
num_iters = 5000 if not smoke_test else 2
for i in range(num_iters):
    # stepの引数は、modelと同じ引数を与える
    elbo = svi.step(is_cont_africa, ruggedness, log_gdp)
    if i % 500 == 0:
        logging.info("Elbo loss: {}".format(elbo))
# Out:
# Elbo loss: 5795.467590510845
# Elbo loss: 415.8169444799423
# Elbo loss: 250.71916329860687
# Elbo loss: 247.19457268714905
# Elbo loss: 249.2004036307335
# Elbo loss: 250.96484470367432
# Elbo loss: 249.35092514753342
# Elbo loss: 248.7831552028656
# Elbo loss: 248.62140649557114
# Elbo loss: 250.4274433851242

# %%
from pyro.infer import Predictive


num_samples = 1000
predictive = Predictive(model, guide=guide, num_samples=num_samples)
svi_samples = {k: v.reshape(num_samples).detach().cpu().numpy()
               for k, v in predictive(log_gdp, is_cont_africa, ruggedness).items()
               if k != "obs"}

# %%
for site, values in summary(svi_samples).items():
    print("Site: {}".format(site))
    print(values, "\n")
# Out:
# Site: a
#       mean       std       5%       25%       50%       75%      95%
# 0  9.17702  0.059607  9.07811  9.140463  9.178211  9.217098  9.27152
#
# Site: bA
#        mean       std       5%       25%       50%       75%       95%
# 0 -1.890622  0.122805 -2.08849 -1.979107 -1.887476 -1.803683 -1.700853
#
# Site: bR
#        mean       std       5%       25%       50%       75%       95%
# 0 -0.157847  0.039538 -0.22324 -0.183673 -0.157873 -0.133102 -0.091713
#
# Site: bAR
#        mean       std        5%       25%       50%       75%       95%
# 0  0.304515  0.067683  0.194583  0.259464  0.304907  0.348932  0.415128
#
# Site: sigma
#        mean       std        5%       25%       50%       75%       95%
# 0  0.902898  0.047971  0.824166  0.870317  0.901981  0.935171  0.981577

# %%
from pyro.infer import MCMC, NUTS


nuts_kernel = NUTS(model)

mcmc = MCMC(nuts_kernel, num_samples=1000, warmup_steps=200)
mcmc.run(is_cont_africa, ruggedness, log_gdp)

hmc_samples = {k: v.detach().cpu().numpy() for k, v in mcmc.get_samples().items()}
# Out:
# Sample: 100%|██████████| 1200/1200 [00:38, 30.83it/s, step size=4.16e-01, acc. prob=0.929]

# %%
sites = ["a", "bA", "bR", "bAR", "sigma"]

fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(12, 10))
fig.suptitle("Marginal Posterior density - Regression Coefficients", fontsize=16)
for i, ax in enumerate(axs.reshape(-1)):
    site = sites[i]
    sns.distplot(svi_samples[site], ax=ax, label="SVI (DiagNormal)")
    sns.distplot(hmc_samples[site], ax=ax, label="HMC")
    ax.set_title(site)
handles, labels = ax.get_legend_handles_labels()
fig.legend(handles, labels, loc='upper right');

# %%
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))
fig.suptitle("Cross-section of the Posterior Distribution", fontsize=16)
sns.kdeplot(hmc_samples["bA"], hmc_samples["bR"], ax=axs[0], shade=True, label="HMC")
sns.kdeplot(svi_samples["bA"], svi_samples["bR"], ax=axs[0], label="SVI (DiagNormal)")
axs[0].set(xlabel="bA", ylabel="bR", xlim=(-2.5, -1.2), ylim=(-0.5, 0.1))
sns.kdeplot(hmc_samples["bR"], hmc_samples["bAR"], ax=axs[1], shade=True, label="HMC")
sns.kdeplot(svi_samples["bR"], svi_samples["bAR"], ax=axs[1], label="SVI (DiagNormal)")
axs[1].set(xlabel="bR", ylabel="bAR", xlim=(-0.45, 0.05), ylim=(-0.15, 0.8))
handles, labels = axs[1].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper right');
